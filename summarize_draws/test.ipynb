# %%
import pandas as pd
import numpy as np
from glob import glob

# %%
male_dir = "/Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/male_draws"
prefix = 'male_blk'

# %%
files = sorted(glob(f"{male_dir}/{prefix}_*.parquet"))
print(f"{len(files)} files loaded from {male_dir}")
# Out:
# 20 files loaded from /Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/male_draws

# %%
df = pd.concat([pd.read_parquet(f, engine="fastparquet") for f in files], axis=1)

# %%
rows, cols = np.where(df_array == 0)
print(list(zip(rows, cols)))  # [(0, 0), (1, 1)]
# Out:
# [(np.int64(74), np.int64(2350)), (np.int64(74), np.int64(3650)), (np.int64(74), np.int64(10398)), (np.int64(74), np.int64(14039)), (np.int64(74), np.int64(16820)), (np.int64(74), np.int64(23220)), (np.int64(74), np.int64(28919)), (np.int64(74), np.int64(28980)), (np.int64(74), np.int64(32085)), (np.int64(74), np.int64(32927)), (np.int64(74), np.int64(33676)), (np.int64(74), np.int64(39279)), (np.int64(74), np.int64(43968)), (np.int64(74), np.int64(44262)), (np.int64(74), np.int64(49233)), (np.int64(74), np.int64(50835)), (np.int64(74), np.int64(56731)), (np.int64(74), np.int64(57257)), (np.int64(74), np.int64(61906)), (np.int64(74), np.int64(65591)), (np.int64(74), np.int64(68650)), (np.int64(74), np.int64(70439)), (np.int64(74), np.int64(71139)), (np.int64(74), np.int64(74542)), (np.int64(74), np.int64(78969)), (np.int64(74), np.int64(79496)), (np.int64(74), np.int64(82789)), (np.int64(74), np.int64(84327)), (np.int64(74), np.int64(87454)), (np.int64(74), np.int64(88749)), (np.int64
# ...

# %%
demo='race'
male_dir = "/Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/male_draws"
male_paths = sorted(glob(f"{male_dir}/adj_male_{demo}_blk*.parquet"))

# %%
msm_dir = "/Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/msm_draws"
msm_paths = sorted(glob(f"{msm_dir}/adj_msm_{demo}_blk*.parquet"))
msm_paths
# Out:
# ['/Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/msm_draws/adj_msm_race_blk_10001_15000.parquet',
#  '/Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/msm_draws/adj_msm_race_blk_15001_20000.parquet',
#  '/Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/msm_draws/adj_msm_race_blk_1_5000.parquet',
#  '/Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/msm_draws/adj_msm_race_blk_20001_25000.parquet',
#  '/Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/msm_draws/adj_msm_race_blk_25001_30000.parquet',
#  '/Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/msm_draws/adj_msm_race_blk_30001_35000.parquet',
#  '/Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/msm_draws/adj_msm_race_blk_35001_40000.parquet',
#  '/Users/meibinchen/Documents/GitHub/MSM-Population-Estimates/msm_draws/adj_msm_race_blk_40001_45000.parquet',
# ...

# %%
df = pd.read_parquet(male_paths[0], engine="fastparquet")
df.loc[df['male_pop']==0]
# Out:
#           race  county_index  sim_index  male_pop
# 21           1             8          1       0.0
# 255          1            86          1       0.0
# 261          1            88          1       0.0
# 612          1           205          1       0.0
# 621          1           208          1       0.0
# ...        ...           ...        ...       ...
# 47159676     1          3037       5000       0.0
# 47159827     2          3087       5000       0.0
# 47159883     1          3106       5000       0.0
# 47159886     1          3107       5000       0.0
# 47159955     1          3130       5000       0.0
#
# [722390 rows x 4 columns]

# %%
df2 = pd.read_parquet(msm_paths[0], engine="fastparquet")
df2.loc[df2['msm_count'].isna(), 'county_index'].unique()
# Out:
# array([ 310,  311,  312,  313,  314,  315,  316,  317,  318, 1761, 1484,
#        1722, 1993, 1997,  130, 2014, 2018, 1765, 1752, 2021, 1762, 2012,
#        2015, 2802, 2157, 2037, 2019, 2007, 2044, 2002, 2020, 1995, 1999,
#        2039, 1750, 1755, 2004, 2008, 1994, 2009, 1996, 2041, 1757, 1760,
#        2016, 2033, 2040, 2034, 3013, 1998, 2023, 2026, 1756, 2038, 2005,
#        1753, 1465, 2003, 2013, 2042, 2035, 2045, 2027, 2011, 2031, 2036,
#        1758, 2029, 2032, 2024, 2006, 1754, 2028, 1504,   88,  589,   68,
#        1472], dtype=int32)

# %%
results, all_rate_summaries = [], []
for start in range(1, n_counties + 1, chunk_size):
    end = min(start + chunk_size - 1, n_counties)
    county_range_set = set(range(start, end + 1))

    with ThreadPoolExecutor(max_workers=8) as executor:
        dfs = list(executor.map(lambda p: safe_read_parquet(p, [demo, "county_index", "sim_index", "msm_count"]), msm_paths))
    dfs = [df[df["county_index"].isin(county_range_set)] for df in dfs if not df.empty]
    if not dfs:
        continue
